# %%
# !pip install mteb -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 19.7 MB/s eta 0:00:00

# %%
import mteb
from sentence_transformers import SentenceTransformer
import pickle
import json

# Load model
model = mteb.get_model(
    "bqbbao6/vietnamese-legal-embedding",
    prompts={
        "query": "query: ",
        "document": "passage: "
    }
)

tasks = mteb.get_task("ZacLegalTextRetrieval")
results_1 = mteb.evaluate(model, tasks=tasks)
print(results_1)

with open("/kaggle/working/results_1.pkl", "wb") as f:
    pickle.dump(results_1, f)

with open("/kaggle/working/results_1.pkl", "rb") as f:
    data = pickle.load(f)

for task_result in data:
    print(f"Task: {task_result.task_name}")
    print(f"Main score: {task_result.main_score}")
    print(json.dumps(task_result.scores, indent=2))
# Out:
# 2026-05-24 10:55:27.190333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779620127.586540      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779620127.704826      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779620128.695215      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779620128.695257      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779620128.695260      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779620128.695262      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/741 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/354 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/312 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# qrels/test.jsonl:   0%|          | 0.00/73.1k [00:00<?, ?B/s]
# qrels/train.jsonl:   0%|          | 0.00/231k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/793 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/2505 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/793 [00:00<?, ? examples/s]
# corpus.jsonl:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Generating corpus split:   0%|          | 0/61425 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/61425 [00:00<?, ? examples/s]
# queries.jsonl:   0%|          | 0.00/552k [00:00<?, ?B/s]
# Generating queries split:   0%|          | 0/3298 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/3298 [00:00<?, ? examples/s]
# Processing queries for dataloading:   0%|          | 0/818 [00:00<?, ? examples/s]
# Standardizing text corpus format:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Standardizing text corpus format:   0%|          | 0/11425 [00:00<?, ? examples/s]
# model_name='bqbbao6/vietnamese-legal-embedding' model_revision='a04255f50c3bd9be4b0f2b36e88d5bae7ef06f1b' task_results=[TaskResult(task_name=ZacLegalTextRetrieval, main_score=0.81, scores=..., ...)] default_modalities=['text'] exceptions=None experiment_name=None
# Task: ZacLegalTextRetrieval
# Main score: 0.80586
# {
#   "test": [
#     {
#       "ndcg_at_1": 0.62817,
#       "ndcg_at_3": 0.76896,
#       "ndcg_at_5": 0.78956,
#       "ndcg_at_10": 0.80586,
#       "ndcg_at_20": 0.81167,
#       "ndcg_at_100": 0.81396,
#       "ndcg_at_1000": 0.81458,
#       "map_at_1": 0.6269,
#       "map_at_3": 0.73604,
#       "map_at_5": 0.74759,
#       "map_at_10": 0.75457,
#       "map_at_20": 0.75628,
#       "map_at_100": 0.75662,
#       "map_at_1000": 0.75666,
#       "recall_at_1": 0.6269,
#       "recall_at_3": 0.86294,
#       "recall_at_5": 0.91244,
#       "recall_at_10": 0.96129,
#       "recall_at_20": 0.9835,
#       "recall_at_100": 0.99556,
#       "recall_at_1000": 1.0,
#       "accuracy": 0.6269,
#       "precision_at_1": 0.62817,
#       "precision_at_3": 0.28892,
#       "precision_at_5": 0.18325,
#       "precision_at_10": 0.09657,
#       "precision_at_20": 0.04943,
#       "precision_at_100": 0.01001,
#       "precision_at_1000": 0.00101,
#       "mrr_at_1": 0.6281725888324873,
#       "mrr_at_3": 0.7354060913705583,
#       "mrr_at_5": 0.7472715736040609,
#       "mrr_at_10": 0.7542935702199661,
#       "mrr_at_20": 0.7558994033818609,
#       "mrr_at_100": 0.7562173272242717,
#       "mrr_at_1000": 0.7562418802773035,
#       "nauc_ndcg_at_1_max": 0.2778434986635182,
#       "nauc_ndcg_at_1_std": -0.11951700559155065,
#       "nauc_ndcg_at_1_diff1": 0.6629749210821629,
#       "nauc_ndcg_at_3_max": 0.3393860323007147,
#       "nauc_ndcg_at_3_std": -0.1347578198425448,
#       "nauc_ndcg_at_3_diff1": 0.6258808155958545,
#       "nauc_ndcg_at_5_max": 0.3168131684514912,
#       "nauc_ndcg_at_5_std": -0.14048753194564467,
#       "nauc_ndcg_at_5_diff1": 0.6112489254111132,
#       "nauc_ndcg_at_10_max": 0.31525018701091845,
#       "nauc_ndcg_at_10_std": -0.14430727422391473,
#       "nauc_ndcg_at_10_diff1": 0.6160140099149126,
#       "nauc_ndcg_at_20_max": 0.31540689878657097,
#       "nauc_ndcg_at_20_std": -0.13523660637135385,
#       "nauc_ndcg_at_20_diff1": 0.6269904215849559,
#       "nauc_ndcg_at_100_max": 0.31566938382887255,
#       "nauc_ndcg_at_100_std": -0.13512022764438905,
#       "nauc_ndcg_at_100_diff1": 0.6278456556180558,
#       "nauc_ndcg_at_1000_max": 0.31519840299033797,
#       "nauc_ndcg_at_1000_std": -0.1349255137534823,
#       "nauc_ndcg_at_1000_diff1": 0.6291856301899533,
#       "nauc_map_at_1_max": 0.27231705463460193,
#       "nauc_map_at_1_std": -0.12659574704633916,
#       "nauc_map_at_1_diff1": 0.6592684662310611,
#       "nauc_map_at_3_max": 0.3226882218955785,
#       "nauc_map_at_3_std": -0.13109922532739257,
#       "nauc_map_at_3_diff1": 0.6356922171246023,
#       "nauc_map_at_5_max": 0.3112950911684592,
#       "nauc_map_at_5_std": -0.1334288657165165,
#       "nauc_map_at_5_diff1": 0.628997416246918,
#       "nauc_map_at_10_max": 0.31021081860738714,
#       "nauc_map_at_10_std": -0.13503487883804824,
#       "nauc_map_at_10_diff1": 0.6307858800130826,
#       "nauc_map_at_20_max": 0.3105819288274059,
#       "nauc_map_at_20_std": -0.13288010233659883,
#       "nauc_map_at_20_diff1": 0.6334467799634179,
#       "nauc_map_at_100_max": 0.3108929630421418,
#       "nauc_map_at_100_std": -0.13266255559122078,
#       "nauc_map_at_100_diff1": 0.6335966630151476,
#       "nauc_map_at_1000_max": 0.31086380599720254,
#       "nauc_map_at_1000_std": -0.1326889912258615,
#       "nauc_map_at_1000_diff1": 0.6336531522839817,
#       "nauc_recall_at_1_max": 0.27231705463460193,
#       "nauc_recall_at_1_std": -0.12659574704633916,
#       "nauc_recall_at_1_diff1": 0.6592684662310611,
#       "nauc_recall_at_3_max": 0.418529658533938,
#       "nauc_recall_at_3_std": -0.1487609240035161,
#       "nauc_recall_at_3_diff1": 0.5815199744644924,
#       "nauc_recall_at_5_max": 0.34420266107615494,
#       "nauc_recall_at_5_std": -0.18660360859709965,
#       "nauc_recall_at_5_diff1": 0.48730357568729554,
#       "nauc_recall_at_10_max": 0.35442678190059174,
#       "nauc_recall_at_10_std": -0.2792146438738953,
#       "nauc_recall_at_10_diff1": 0.396598850039063,
#       "nauc_recall_at_20_max": 0.3807662450041405,
#       "nauc_recall_at_20_std": -0.1334478352346698,
#       "nauc_recall_at_20_diff1": 0.5003487882038045,
#       "nauc_recall_at_100_max": 0.414803420491853,
#       "nauc_recall_at_100_std": -0.251909218296375,
#       "nauc_recall_at_100_diff1": 0.29324262576751225,
#       "nauc_recall_at_1000_max": NaN,
#       "nauc_recall_at_1000_std": NaN,
#       "nauc_recall_at_1000_diff1": NaN,
#       "nauc_precision_at_1_max": 0.2778434986635182,
#       "nauc_precision_at_1_std": -0.11951700559155065,
#       "nauc_precision_at_1_diff1": 0.6629749210821629,
#       "nauc_precision_at_3_max": 0.42761758960339863,
#       "nauc_precision_at_3_std": -0.11764981400638468,
#       "nauc_precision_at_3_diff1": 0.5674775401098763,
#       "nauc_precision_at_5_max": 0.36112376684008735,
#       "nauc_precision_at_5_std": -0.13907205905032008,
#       "nauc_precision_at_5_diff1": 0.4706452617059162,
#       "nauc_precision_at_10_max": 0.42310092978170766,
#       "nauc_precision_at_10_std": -0.1692019578106433,
#       "nauc_precision_at_10_diff1": 0.3816433962494387,
#       "nauc_precision_at_20_max": 0.4542387024167033,
#       "nauc_precision_at_20_std": 0.05375248778996918,
#       "nauc_precision_at_20_diff1": 0.36613223415225565,
#       "nauc_precision_at_100_max": 0.5215202117999292,
#       "nauc_precision_at_100_std": 0.1873290884315171,
#       "nauc_precision_at_100_diff1": 0.11117299393785364,
#       "nauc_precision_at_1000_max": 0.4095825724057234,
#       "nauc_precision_at_1000_std": 0.2954061699639603,
#       "nauc_precision_at_1000_diff1": -0.048345162917247775,
#       "nauc_mrr_at_1_max": 0.2778434986635182,
#       "nauc_mrr_at_1_std": -0.11951700559155065,
#       "nauc_mrr_at_1_diff1": 0.6629749210821629,
#       "nauc_mrr_at_3_max": 0.32103832155288825,
#       "nauc_mrr_at_3_std": -0.1325051431628938,
#       "nauc_mrr_at_3_diff1": 0.6349207855481156,
#       "nauc_mrr_at_5_max": 0.30871970622343836,
#       "nauc_mrr_at_5_std": -0.13656233947975593,
#       "nauc_mrr_at_5_diff1": 0.6275645287755406,
#       "nauc_mrr_at_10_max": 0.30873348258140765,
#       "nauc_mrr_at_10_std": -0.13817871853434713,
#       "nauc_mrr_at_10_diff1": 0.6300213054885992,
#       "nauc_mrr_at_20_max": 0.3090177676606442,
#       "nauc_mrr_at_20_std": -0.13565194181422974,
#       "nauc_mrr_at_20_diff1": 0.6328963159900886,
#       "nauc_mrr_at_100_max": 0.30909507967735683,
#       "nauc_mrr_at_100_std": -0.13544340905284932,
#       "nauc_mrr_at_100_diff1": 0.6329101551055271,
#       "nauc_mrr_at_1000_max": 0.30906771037382186,
#       "nauc_mrr_at_1000_std": -0.13545071770253334,
#       "nauc_mrr_at_1000_diff1": 0.632980801435635,
#       "hit_rate_at_1": 0.62817,
#       "hit_rate_at_3": 0.86421,
#       "hit_rate_at_5": 0.91371,
#       "hit_rate_at_10": 0.9632,
#       "hit_rate_at_20": 0.98477,
#       "hit_rate_at_100": 0.99619,
#       "hit_rate_at_1000": 1.0,
#       "main_score": 0.80586,
#       "hf_subset": "default",
#       "languages": [
#         "vie-Latn"
#       ]
#     }
#   ]
# }

# %%
model = mteb.get_model(
    "intfloat/multilingual-e5-base",
    prompts={
        "query": "query: ",
        "document": "passage: "
    }
)

results_2 = mteb.evaluate(model, tasks=tasks)
print(results_2)

with open("/kaggle/working/results_2.pkl", "wb") as f:
    pickle.dump(results_2, f)

with open("/kaggle/working/results_2.pkl", "rb") as f:
    data = pickle.load(f)

for task_result in data:
    print(f"Task: {task_result.task_name}")
    print(f"Main score: {task_result.main_score}")
    print(json.dumps(task_result.scores, indent=2))
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# XLMRobertaModel LOAD REPORT from: intfloat/multilingual-e5-base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# Model prompts specified, these will overwrite the default model prompts. Current prompts will be:
#  {'query': 'query: ', 'document': 'passage: '}
# /usr/local/lib/python3.12/dist-packages/mteb/models/sentence_transformer_wrapper.py:113: UserWarning: Model prompts specified, these will overwrite the default model prompts. Current prompts will be:
#  {'query': 'query: ', 'document': 'passage: '}
#   warnings.warn(msg)
# model_name='intfloat/multilingual-e5-base' model_revision='d13f1b27baf31030b7fd040960d60d909913633f' task_results=[TaskResult(task_name=ZacLegalTextRetrieval, main_score=0.60, scores=..., ...)] default_modalities=['text'] exceptions=None experiment_name=None
# Task: ZacLegalTextRetrieval
# Main score: 0.60296
# {
#   "test": [
#     {
#       "ndcg_at_1": 0.44797,
#       "ndcg_at_3": 0.54696,
#       "ndcg_at_5": 0.57669,
#       "ndcg_at_10": 0.60296,
#       "ndcg_at_20": 0.62487,
#       "ndcg_at_100": 0.64552,
#       "ndcg_at_1000": 0.64948,
#       "map_at_1": 0.4467,
#       "map_at_3": 0.52126,
#       "map_at_5": 0.5382,
#       "map_at_10": 0.54911,
#       "map_at_20": 0.55517,
#       "map_at_100": 0.55838,
#       "map_at_1000": 0.55853,
#       "recall_at_1": 0.4467,
#       "recall_at_3": 0.62056,
#       "recall_at_5": 0.69162,
#       "recall_at_10": 0.77221,
#       "recall_at_20": 0.8585,
#       "recall_at_100": 0.96447,
#       "recall_at_1000": 0.99556,
#       "accuracy": 0.4467,
#       "precision_at_1": 0.44797,
#       "precision_at_3": 0.2077,
#       "precision_at_5": 0.13909,
#       "precision_at_10": 0.07766,
#       "precision_at_20": 0.04315,
#       "precision_at_100": 0.0097,
#       "precision_at_1000": 0.001,
#       "mrr_at_1": 0.44543147208121825,
#       "mrr_at_3": 0.5209390862944162,
#       "mrr_at_5": 0.5369289340101523,
#       "mrr_at_10": 0.5481619128192733,
#       "mrr_at_20": 0.5542122422636637,
#       "mrr_at_100": 0.5574457896866195,
#       "mrr_at_1000": 0.5575903157610835,
#       "nauc_ndcg_at_1_max": 0.4666986186000552,
#       "nauc_ndcg_at_1_std": 0.03029898961875273,
#       "nauc_ndcg_at_1_diff1": 0.5792426023739606,
#       "nauc_ndcg_at_3_max": 0.48674976585294305,
#       "nauc_ndcg_at_3_std": 0.06048072295667159,
#       "nauc_ndcg_at_3_diff1": 0.5207109142680756,
#       "nauc_ndcg_at_5_max": 0.5106769256226654,
#       "nauc_ndcg_at_5_std": 0.09294380058934286,
#       "nauc_ndcg_at_5_diff1": 0.5123466900023177,
#       "nauc_ndcg_at_10_max": 0.5069427876308125,
#       "nauc_ndcg_at_10_std": 0.0759692411228601,
#       "nauc_ndcg_at_10_diff1": 0.5024928933248942,
#       "nauc_ndcg_at_20_max": 0.5007870270826073,
#       "nauc_ndcg_at_20_std": 0.07489120046963858,
#       "nauc_ndcg_at_20_diff1": 0.49515929678780013,
#       "nauc_ndcg_at_100_max": 0.49921648372783833,
#       "nauc_ndcg_at_100_std": 0.0814279765855808,
#       "nauc_ndcg_at_100_diff1": 0.5112045835164499,
#       "nauc_ndcg_at_1000_max": 0.49776267299684923,
#       "nauc_ndcg_at_1000_std": 0.07394363040423133,
#       "nauc_ndcg_at_1000_diff1": 0.5179593816526218,
#       "nauc_map_at_1_max": 0.4613586754259172,
#       "nauc_map_at_1_std": 0.028876091415435887,
#       "nauc_map_at_1_diff1": 0.5748966898878615,
#       "nauc_map_at_3_max": 0.48050743995389317,
#       "nauc_map_at_3_std": 0.05300651709516266,
#       "nauc_map_at_3_diff1": 0.5336433843864359,
#       "nauc_map_at_5_max": 0.4942505548740758,
#       "nauc_map_at_5_std": 0.07046394553454909,
#       "nauc_map_at_5_diff1": 0.5302067327729417,
#       "nauc_map_at_10_max": 0.49237717100158723,
#       "nauc_map_at_10_std": 0.0633869272485757,
#       "nauc_map_at_10_diff1": 0.5272451939962599,
#       "nauc_map_at_20_max": 0.4905157650610889,
#       "nauc_map_at_20_std": 0.06291413397342736,
#       "nauc_map_at_20_diff1": 0.5259718115184235,
#       "nauc_map_at_100_max": 0.49011806190941426,
#       "nauc_map_at_100_std": 0.06340974831526912,
#       "nauc_map_at_100_diff1": 0.5282123110705893,
#       "nauc_map_at_1000_max": 0.4901021726498902,
#       "nauc_map_at_1000_std": 0.06321979297709734,
#       "nauc_map_at_1000_diff1": 0.5284724451048856,
#       "nauc_recall_at_1_max": 0.4613586754259172,
#       "nauc_recall_at_1_std": 0.028876091415435887,
#       "nauc_recall_at_1_diff1": 0.5748966898878615,
#       "nauc_recall_at_3_max": 0.4998245086211777,
#       "nauc_recall_at_3_std": 0.08239683835494398,
#       "nauc_recall_at_3_diff1": 0.4742054482532274,
#       "nauc_recall_at_5_max": 0.5687590026146164,
#       "nauc_recall_at_5_std": 0.17711166010016285,
#       "nauc_recall_at_5_diff1": 0.4445069634160845,
#       "nauc_recall_at_10_max": 0.5688699912580476,
#       "nauc_recall_at_10_std": 0.12788134554657488,
#       "nauc_recall_at_10_diff1": 0.38090679089616286,
#       "nauc_recall_at_20_max": 0.5545680012131305,
#       "nauc_recall_at_20_std": 0.14670811567125433,
#       "nauc_recall_at_20_diff1": 0.25722217124172697,
#       "nauc_recall_at_100_max": 0.6434612628388143,
#       "nauc_recall_at_100_std": 0.6195863685687814,
#       "nauc_recall_at_100_diff1": 0.17134090668666238,
#       "nauc_recall_at_1000_max": 0.8709484797893572,
#       "nauc_recall_at_1000_std": 0.9229400457879424,
#       "nauc_recall_at_1000_diff1": 0.5911461762417204,
#       "nauc_precision_at_1_max": 0.4666986186000552,
#       "nauc_precision_at_1_std": 0.03029898961875273,
#       "nauc_precision_at_1_diff1": 0.5792426023739606,
#       "nauc_precision_at_3_max": 0.5106144956286554,
#       "nauc_precision_at_3_std": 0.09087983008742706,
#       "nauc_precision_at_3_diff1": 0.4736541786594855,
#       "nauc_precision_at_5_max": 0.5765560296696438,
#       "nauc_precision_at_5_std": 0.18465459442298876,
#       "nauc_precision_at_5_diff1": 0.44104637285048953,
#       "nauc_precision_at_10_max": 0.5789098287848103,
#       "nauc_precision_at_10_std": 0.13709938568206562,
#       "nauc_precision_at_10_diff1": 0.3767238421721677,
#       "nauc_precision_at_20_max": 0.5706117728202575,
#       "nauc_precision_at_20_std": 0.15981641457642667,
#       "nauc_precision_at_20_diff1": 0.2564736020952751,
#       "nauc_precision_at_100_max": 0.7243365271608225,
#       "nauc_precision_at_100_std": 0.6039921114290043,
#       "nauc_precision_at_100_diff1": 0.2114575540163155,
#       "nauc_precision_at_1000_max": 0.9278968257660143,
#       "nauc_precision_at_1000_std": 0.5302973378926465,
#       "nauc_precision_at_1000_diff1": 0.49764512967075153,
#       "nauc_mrr_at_1_max": 0.464722109868132,
#       "nauc_mrr_at_1_std": 0.03083348131330612,
#       "nauc_mrr_at_1_diff1": 0.5858453623335428,
#       "nauc_mrr_at_3_max": 0.4833698641503434,
#       "nauc_mrr_at_3_std": 0.05314742033056132,
#       "nauc_mrr_at_3_diff1": 0.5411514941217663,
#       "nauc_mrr_at_5_max": 0.49344350331195613,
#       "nauc_mrr_at_5_std": 0.06930634294986159,
#       "nauc_mrr_at_5_diff1": 0.5361866081166418,
#       "nauc_mrr_at_10_max": 0.4921076425918223,
#       "nauc_mrr_at_10_std": 0.06212104300844009,
#       "nauc_mrr_at_10_diff1": 0.532742681343519,
#       "nauc_mrr_at_20_max": 0.4902194083039885,
#       "nauc_mrr_at_20_std": 0.06160192149861882,
#       "nauc_mrr_at_20_diff1": 0.5315601341352236,
#       "nauc_mrr_at_100_max": 0.489961350392588,
#       "nauc_mrr_at_100_std": 0.06208076553865754,
#       "nauc_mrr_at_100_diff1": 0.5339984929756534,
#       "nauc_mrr_at_1000_max": 0.489906115190302,
#       "nauc_mrr_at_1000_std": 0.06189132410463993,
#       "nauc_mrr_at_1000_diff1": 0.5342212545424995,
#       "hit_rate_at_1": 0.44797,
#       "hit_rate_at_3": 0.62183,
#       "hit_rate_at_5": 0.69162,
#       "hit_rate_at_10": 0.77284,
#       "hit_rate_at_20": 0.85914,
#       "hit_rate_at_100": 0.96574,
#       "hit_rate_at_1000": 0.99619,
#       "main_score": 0.60296,
#       "hf_subset": "default",
#       "languages": [
#         "vie-Latn"
#       ]
#     }
#   ]
# }

# %%
model = mteb.get_model("bkai-foundation-models/vietnamese-bi-encoder")
results_3 = mteb.evaluate(model, tasks=tasks)
print(results_3)

with open("/kaggle/working/results_3.pkl", "wb") as f:
    pickle.dump(results_3, f)

with open("/kaggle/working/results_3.pkl", "rb") as f:
    data = pickle.load(f)

for task_result in data:
    print(f"Task: {task_result.task_name}")
    print(f"Main score: {task_result.main_score}")
    print(json.dumps(task_result.scores, indent=2))
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# model_name='bkai-foundation-models/vietnamese-bi-encoder' model_revision='84f9d9ada0d1a3c37557398b9ae9fcedcdf40be0' task_results=[TaskResult(task_name=ZacLegalTextRetrieval, main_score=0.62, scores=..., ...)] default_modalities=['text'] exceptions=None experiment_name=None
# Task: ZacLegalTextRetrieval
# Main score: 0.61604
# {
#   "test": [
#     {
#       "ndcg_at_1": 0.44543,
#       "ndcg_at_3": 0.55934,
#       "ndcg_at_5": 0.59052,
#       "ndcg_at_10": 0.61604,
#       "ndcg_at_20": 0.62945,
#       "ndcg_at_100": 0.64418,
#       "ndcg_at_1000": 0.65159,
#       "map_at_1": 0.44416,
#       "map_at_3": 0.53099,
#       "map_at_5": 0.54818,
#       "map_at_10": 0.55883,
#       "map_at_20": 0.56264,
#       "map_at_100": 0.56472,
#       "map_at_1000": 0.56499,
#       "recall_at_1": 0.44416,
#       "recall_at_3": 0.64086,
#       "recall_at_5": 0.71701,
#       "recall_at_10": 0.79505,
#       "recall_at_20": 0.84708,
#       "recall_at_100": 0.92576,
#       "recall_at_1000": 0.98477,
#       "accuracy": 0.44416,
#       "precision_at_1": 0.44543,
#       "precision_at_3": 0.21489,
#       "precision_at_5": 0.14416,
#       "precision_at_10": 0.07995,
#       "precision_at_20": 0.04258,
#       "precision_at_100": 0.0093,
#       "precision_at_1000": 0.00099,
#       "mrr_at_1": 0.44416243654822335,
#       "mrr_at_3": 0.5287648054145516,
#       "mrr_at_5": 0.5469754653130288,
#       "mrr_at_10": 0.5579370115220369,
#       "mrr_at_20": 0.5617528517576745,
#       "mrr_at_100": 0.5638324460978398,
#       "mrr_at_1000": 0.5640703239097419,
#       "nauc_ndcg_at_1_max": 0.5625243060294141,
#       "nauc_ndcg_at_1_std": 0.1284898566965632,
#       "nauc_ndcg_at_1_diff1": 0.5771631159276349,
#       "nauc_ndcg_at_3_max": 0.5734512909785265,
#       "nauc_ndcg_at_3_std": 0.14799775373848806,
#       "nauc_ndcg_at_3_diff1": 0.5113324496503913,
#       "nauc_ndcg_at_5_max": 0.5769616471340523,
#       "nauc_ndcg_at_5_std": 0.16503544256135094,
#       "nauc_ndcg_at_5_diff1": 0.4982726945078876,
#       "nauc_ndcg_at_10_max": 0.572826974514166,
#       "nauc_ndcg_at_10_std": 0.1718463732298096,
#       "nauc_ndcg_at_10_diff1": 0.4904161998232303,
#       "nauc_ndcg_at_20_max": 0.574810113100786,
#       "nauc_ndcg_at_20_std": 0.16751425782192456,
#       "nauc_ndcg_at_20_diff1": 0.4995786181539358,
#       "nauc_ndcg_at_100_max": 0.5738590286590168,
#       "nauc_ndcg_at_100_std": 0.1707275496480072,
#       "nauc_ndcg_at_100_diff1": 0.5095121661347914,
#       "nauc_ndcg_at_1000_max": 0.574125417865863,
#       "nauc_ndcg_at_1000_std": 0.16729508256215878,
#       "nauc_ndcg_at_1000_diff1": 0.5128900613646635,
#       "nauc_map_at_1_max": 0.557147198241196,
#       "nauc_map_at_1_std": 0.12806762844507857,
#       "nauc_map_at_1_diff1": 0.57508479078232,
#       "nauc_map_at_3_max": 0.5709568231286694,
#       "nauc_map_at_3_std": 0.14305479372406227,
#       "nauc_map_at_3_diff1": 0.5274424391141912,
#       "nauc_map_at_5_max": 0.5725698046233378,
#       "nauc_map_at_5_std": 0.15152210851933043,
#       "nauc_map_at_5_diff1": 0.5209551450901438,
#       "nauc_map_at_10_max": 0.5712993366538525,
#       "nauc_map_at_10_std": 0.15421872702369657,
#       "nauc_map_at_10_diff1": 0.5185949564373356,
#       "nauc_map_at_20_max": 0.5716775649714647,
#       "nauc_map_at_20_std": 0.15303990365944914,
#       "nauc_map_at_20_diff1": 0.521103888564668,
#       "nauc_map_at_100_max": 0.5717274927754648,
#       "nauc_map_at_100_std": 0.15349559746251115,
#       "nauc_map_at_100_diff1": 0.5225958477290251,
#       "nauc_map_at_1000_max": 0.5717841771083331,
#       "nauc_map_at_1000_std": 0.1534456971270549,
#       "nauc_map_at_1000_diff1": 0.5226889846901954,
#       "nauc_recall_at_1_max": 0.557147198241196,
#       "nauc_recall_at_1_std": 0.12806762844507857,
#       "nauc_recall_at_1_diff1": 0.57508479078232,
#       "nauc_recall_at_3_max": 0.5782423635592713,
#       "nauc_recall_at_3_std": 0.16340382596556902,
#       "nauc_recall_at_3_diff1": 0.457069914652032,
#       "nauc_recall_at_5_max": 0.5899403479866087,
#       "nauc_recall_at_5_std": 0.21826454239368712,
#       "nauc_recall_at_5_diff1": 0.4089542960660888,
#       "nauc_recall_at_10_max": 0.571308066573224,
#       "nauc_recall_at_10_std": 0.26148548018393675,
#       "nauc_recall_at_10_diff1": 0.34540272433118874,
#       "nauc_recall_at_20_max": 0.5858053884362816,
#       "nauc_recall_at_20_std": 0.2559954046167792,
#       "nauc_recall_at_20_diff1": 0.3678906695204258,
#       "nauc_recall_at_100_max": 0.565766615446301,
#       "nauc_recall_at_100_std": 0.3904414483802577,
#       "nauc_recall_at_100_diff1": 0.41485820753308533,
#       "nauc_recall_at_1000_max": 0.5448170994172385,
#       "nauc_recall_at_1000_std": 0.7292650035655389,
#       "nauc_recall_at_1000_diff1": 0.5352378053053722,
#       "nauc_precision_at_1_max": 0.5625243060294141,
#       "nauc_precision_at_1_std": 0.1284898566965632,
#       "nauc_precision_at_1_diff1": 0.5771631159276349,
#       "nauc_precision_at_3_max": 0.5874891007953058,
#       "nauc_precision_at_3_std": 0.16352053414063225,
#       "nauc_precision_at_3_diff1": 0.4579315219957135,
#       "nauc_precision_at_5_max": 0.6011838844315054,
#       "nauc_precision_at_5_std": 0.21777597286655034,
#       "nauc_precision_at_5_diff1": 0.41103154704927003,
#       "nauc_precision_at_10_max": 0.5863648638290457,
#       "nauc_precision_at_10_std": 0.25951879159199887,
#       "nauc_precision_at_10_diff1": 0.3506152578818291,
#       "nauc_precision_at_20_max": 0.6062082319251267,
#       "nauc_precision_at_20_std": 0.254029805777052,
#       "nauc_precision_at_20_diff1": 0.3749083036344728,
#       "nauc_precision_at_100_max": 0.6078765540420976,
#       "nauc_precision_at_100_std": 0.38306905996439117,
#       "nauc_precision_at_100_diff1": 0.4281223325783891,
#       "nauc_precision_at_1000_max": 0.5306076716163247,
#       "nauc_precision_at_1000_std": 0.4444923307543753,
#       "nauc_precision_at_1000_diff1": 0.41752668509457147,
#       "nauc_mrr_at_1_max": 0.5658315422524082,
#       "nauc_mrr_at_1_std": 0.13198654116717873,
#       "nauc_mrr_at_1_diff1": 0.5804639625728276,
#       "nauc_mrr_at_3_max": 0.5728521488104038,
#       "nauc_mrr_at_3_std": 0.14367336859812518,
#       "nauc_mrr_at_3_diff1": 0.5344298715539803,
#       "nauc_mrr_at_5_max": 0.5746486281039741,
#       "nauc_mrr_at_5_std": 0.15230861353752218,
#       "nauc_mrr_at_5_diff1": 0.5263231887571105,
#       "nauc_mrr_at_10_max": 0.5738460437913735,
#       "nauc_mrr_at_10_std": 0.15512969422649145,
#       "nauc_mrr_at_10_diff1": 0.5238632764889115,
#       "nauc_mrr_at_20_max": 0.5742537309366066,
#       "nauc_mrr_at_20_std": 0.15396185036775073,
#       "nauc_mrr_at_20_diff1": 0.5264292330438928,
#       "nauc_mrr_at_100_max": 0.5743192366498866,
#       "nauc_mrr_at_100_std": 0.1544228940934684,
#       "nauc_mrr_at_100_diff1": 0.5279526804457803,
#       "nauc_mrr_at_1000_max": 0.5742957734053796,
#       "nauc_mrr_at_1000_std": 0.15435230601613567,
#       "nauc_mrr_at_1000_diff1": 0.5279849702149265,
#       "hit_rate_at_1": 0.44543,
#       "hit_rate_at_3": 0.64213,
#       "hit_rate_at_5": 0.71827,
#       "hit_rate_at_10": 0.79695,
#       "hit_rate_at_20": 0.84898,
#       "hit_rate_at_100": 0.92766,
#       "hit_rate_at_1000": 0.98477,
#       "main_score": 0.61604,
#       "hf_subset": "default",
#       "languages": [
#         "vie-Latn"
#       ]
#     }
#   ]
# }

# %%
model = mteb.get_model("huyydangg/DEk21_hcmute_embedding")
results_4 = mteb.evaluate(model, tasks=tasks)
print(results_4)

with open("/kaggle/working/results_4.pkl", "wb") as f:
    pickle.dump(results_4, f)

with open("/kaggle/working/results_4.pkl", "rb") as f:
    data = pickle.load(f)

for task_result in data:
    print(f"Task: {task_result.task_name}")
    print(f"Main score: {task_result.main_score}")
    print(json.dumps(task_result.scores, indent=2))
# Out:
# config.json:   0%|          | 0.00/672 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/965 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# model_name='huyydangg/DEk21_hcmute_embedding' model_revision='501df2abd66bfecf9f294c4d17741b0d9f3ebb7e' task_results=[TaskResult(task_name=ZacLegalTextRetrieval, main_score=0.71, scores=..., ...)] default_modalities=['text'] exceptions=None experiment_name=None
# Task: ZacLegalTextRetrieval
# Main score: 0.70702
# {
#   "test": [
#     {
#       "ndcg_at_1": 0.54315,
#       "ndcg_at_3": 0.6607,
#       "ndcg_at_5": 0.68872,
#       "ndcg_at_10": 0.70702,
#       "ndcg_at_20": 0.71663,
#       "ndcg_at_100": 0.72865,
#       "ndcg_at_1000": 0.73192,
#       "map_at_1": 0.54124,
#       "map_at_3": 0.63198,
#       "map_at_5": 0.64765,
#       "map_at_10": 0.65542,
#       "map_at_20": 0.65806,
#       "map_at_100": 0.65979,
#       "map_at_1000": 0.65994,
#       "recall_at_1": 0.54124,
#       "recall_at_3": 0.74239,
#       "recall_at_5": 0.81028,
#       "recall_at_10": 0.86548,
#       "recall_at_20": 0.90355,
#       "recall_at_100": 0.96701,
#       "recall_at_1000": 0.99175,
#       "accuracy": 0.54124,
#       "precision_at_1": 0.54315,
#       "precision_at_3": 0.24831,
#       "precision_at_5": 0.16269,
#       "precision_at_10": 0.08693,
#       "precision_at_20": 0.04537,
#       "precision_at_100": 0.00972,
#       "precision_at_1000": 0.001,
#       "mrr_at_1": 0.5431472081218274,
#       "mrr_at_3": 0.6315566835871405,
#       "mrr_at_5": 0.6478637901861252,
#       "mrr_at_10": 0.6556885021352026,
#       "mrr_at_20": 0.6583163952669383,
#       "mrr_at_100": 0.6600328545161505,
#       "mrr_at_1000": 0.6601655525652893,
#       "nauc_ndcg_at_1_max": 0.44058054124463697,
#       "nauc_ndcg_at_1_std": 0.10070817049770202,
#       "nauc_ndcg_at_1_diff1": 0.559775821107033,
#       "nauc_ndcg_at_3_max": 0.45672483632874245,
#       "nauc_ndcg_at_3_std": 0.07767747914452025,
#       "nauc_ndcg_at_3_diff1": 0.5478937193247607,
#       "nauc_ndcg_at_5_max": 0.4393935614346062,
#       "nauc_ndcg_at_5_std": 0.08090614302731663,
#       "nauc_ndcg_at_5_diff1": 0.5468170413221832,
#       "nauc_ndcg_at_10_max": 0.44273676213511226,
#       "nauc_ndcg_at_10_std": 0.08511847782684161,
#       "nauc_ndcg_at_10_diff1": 0.5412889976034042,
#       "nauc_ndcg_at_20_max": 0.4478645234778246,
#       "nauc_ndcg_at_20_std": 0.09016057521043275,
#       "nauc_ndcg_at_20_diff1": 0.539819333947212,
#       "nauc_ndcg_at_100_max": 0.4505486117145856,
#       "nauc_ndcg_at_100_std": 0.09490119152760192,
#       "nauc_ndcg_at_100_diff1": 0.5390576389791073,
#       "nauc_ndcg_at_1000_max": 0.4483262594727158,
#       "nauc_ndcg_at_1000_std": 0.09298314713722788,
#       "nauc_ndcg_at_1000_diff1": 0.5416972539285582,
#       "nauc_map_at_1_max": 0.43611781234192787,
#       "nauc_map_at_1_std": 0.10064799063003708,
#       "nauc_map_at_1_diff1": 0.5558172321812848,
#       "nauc_map_at_3_max": 0.4523910041262513,
#       "nauc_map_at_3_std": 0.08414269508128892,
#       "nauc_map_at_3_diff1": 0.5466101599849496,
#       "nauc_map_at_5_max": 0.4437718252604151,
#       "nauc_map_at_5_std": 0.08569663435786855,
#       "nauc_map_at_5_diff1": 0.5471292322467847,
#       "nauc_map_at_10_max": 0.44489465962627256,
#       "nauc_map_at_10_std": 0.08754637308775592,
#       "nauc_map_at_10_diff1": 0.5444906921765531,
#       "nauc_map_at_20_max": 0.4461225418011112,
#       "nauc_map_at_20_std": 0.08863348011271174,
#       "nauc_map_at_20_diff1": 0.5441638859591432,
#       "nauc_map_at_100_max": 0.44671933690670046,
#       "nauc_map_at_100_std": 0.08936779205550001,
#       "nauc_map_at_100_diff1": 0.5442010580716014,
#       "nauc_map_at_1000_max": 0.44666947842752736,
#       "nauc_map_at_1000_std": 0.08936440820194895,
#       "nauc_map_at_1000_diff1": 0.5443251635262559,
#       "nauc_recall_at_1_max": 0.43611781234192787,
#       "nauc_recall_at_1_std": 0.10064799063003708,
#       "nauc_recall_at_1_diff1": 0.5558172321812848,
#       "nauc_recall_at_3_max": 0.4684697725894312,
#       "nauc_recall_at_3_std": 0.05298988337088847,
#       "nauc_recall_at_3_diff1": 0.548105257665455,
#       "nauc_recall_at_5_max": 0.4119377166659619,
#       "nauc_recall_at_5_std": 0.05763724922652499,
#       "nauc_recall_at_5_diff1": 0.5415863061245174,
#       "nauc_recall_at_10_max": 0.41987943197422206,
#       "nauc_recall_at_10_std": 0.0718451865724762,
#       "nauc_recall_at_10_diff1": 0.5118320603165146,
#       "nauc_recall_at_20_max": 0.458774983014182,
#       "nauc_recall_at_20_std": 0.11626533457249667,
#       "nauc_recall_at_20_diff1": 0.4872651018389049,
#       "nauc_recall_at_100_max": 0.5379736874231908,
#       "nauc_recall_at_100_std": 0.3077792842029755,
#       "nauc_recall_at_100_diff1": 0.3545980160983454,
#       "nauc_recall_at_1000_max": 0.33839171719302796,
#       "nauc_recall_at_1000_std": 0.4693986931739537,
#       "nauc_recall_at_1000_diff1": 0.28634680622848385,
#       "nauc_precision_at_1_max": 0.44058054124463697,
#       "nauc_precision_at_1_std": 0.10070817049770202,
#       "nauc_precision_at_1_diff1": 0.559775821107033,
#       "nauc_precision_at_3_max": 0.4742268234729786,
#       "nauc_precision_at_3_std": 0.05149366088231424,
#       "nauc_precision_at_3_diff1": 0.5488111939886849,
#       "nauc_precision_at_5_max": 0.41576367499161987,
#       "nauc_precision_at_5_std": 0.05186595652454696,
#       "nauc_precision_at_5_diff1": 0.5409343914488127,
#       "nauc_precision_at_10_max": 0.43208197483673927,
#       "nauc_precision_at_10_std": 0.059722914824023164,
#       "nauc_precision_at_10_diff1": 0.5221900967774015,
#       "nauc_precision_at_20_max": 0.4745863806894818,
#       "nauc_precision_at_20_std": 0.09875252148308325,
#       "nauc_precision_at_20_diff1": 0.5027619184986601,
#       "nauc_precision_at_100_max": 0.5634959389355737,
#       "nauc_precision_at_100_std": 0.20858554005917104,
#       "nauc_precision_at_100_diff1": 0.39969715150068214,
#       "nauc_precision_at_1000_max": 0.41101059622375963,
#       "nauc_precision_at_1000_std": 0.14874411921763198,
#       "nauc_precision_at_1000_diff1": 0.3595417076781984,
#       "nauc_mrr_at_1_max": 0.44058054124463697,
#       "nauc_mrr_at_1_std": 0.10070817049770202,
#       "nauc_mrr_at_1_diff1": 0.559775821107033,
#       "nauc_mrr_at_3_max": 0.4533613252872927,
#       "nauc_mrr_at_3_std": 0.07946038613092488,
#       "nauc_mrr_at_3_diff1": 0.5528382525463433,
#       "nauc_mrr_at_5_max": 0.4443078572446977,
#       "nauc_mrr_at_5_std": 0.08554634525455528,
#       "nauc_mrr_at_5_diff1": 0.5503415683223278,
#       "nauc_mrr_at_10_max": 0.445795049765109,
#       "nauc_mrr_at_10_std": 0.08717173474346684,
#       "nauc_mrr_at_10_diff1": 0.5483279637877361,
#       "nauc_mrr_at_20_max": 0.44702234199092006,
#       "nauc_mrr_at_20_std": 0.08827934465340999,
#       "nauc_mrr_at_20_diff1": 0.5480368973078953,
#       "nauc_mrr_at_100_max": 0.4474690366488609,
#       "nauc_mrr_at_100_std": 0.08909455074997896,
#       "nauc_mrr_at_100_diff1": 0.5478167327220581,
#       "nauc_mrr_at_1000_max": 0.44740637262182287,
#       "nauc_mrr_at_1000_std": 0.0890435912353187,
#       "nauc_mrr_at_1000_diff1": 0.5479397921675595,
#       "hit_rate_at_1": 0.54315,
#       "hit_rate_at_3": 0.74365,
#       "hit_rate_at_5": 0.81091,
#       "hit_rate_at_10": 0.86675,
#       "hit_rate_at_20": 0.90482,
#       "hit_rate_at_100": 0.96827,
#       "hit_rate_at_1000": 0.99239,
#       "main_score": 0.70702,
#       "hf_subset": "default",
#       "languages": [
#         "vie-Latn"
#       ]
#     }
#   ]
# }
